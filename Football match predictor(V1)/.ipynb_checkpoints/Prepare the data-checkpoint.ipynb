# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data.csv')
data.dropna(inplace=True)
data = data.reset_index(drop=True)
Labels = ['Home_Team', 'Away_team', 'Home_score', 'Away_score', 'Season']

# %%
data["Result"] = data.apply(
    lambda row: "Win" if row["Home_score"] > row["Away_score"]
    else "Loss" if row["Home_score"] < row["Away_score"]
    else "Draw", axis=1
)
data
# Out:
#         Unnamed: 0               Home_Team               Away_team  \
# 0                0               Barcelona                Valencia
# 1                1  RC Deportivo La Coruña               Barcelona
# 2                2               Barcelona             Real Madrid
# 3                3               Barcelona           Athletic Club
# 4                4              Las Palmas               Barcelona
# ...            ...                     ...                     ...
# 155362      156610   Racing Club de France   FC Sochaux-Montb?iard
# 155363      156611                 RC Lens                FC Nancy
# 155364      156612    RC Strasbourg Alsace          N?es Olympique
# 155365      156613             Le Havre AC  Olympique de Marseille
# 155366      156614              LOSC Lille           Stade fran?is
#
#         Home_score  Away_score     Season Result
# 0              2.0         1.0  2017/2018    Win
# 1              2.0         4.0  2017/2018   Loss
# 2              2.0         2.0  2017/2018   Draw
# 3              2.0         0.0  2017/2018    Win
# 4              1.0         1.0  2017/2018   Draw
# ...            ...         ...        ...    ...
# 155362         4.0         1.0  1950-1951    Win
# 155363         0.0         2.0  1950-1951   Loss
# 155364         2.0         1.0  1950-1951    Win
# 155365         1.0         0.0  1950-1951    Win
# 155366         1.0         1.0  1950-1951   Draw
#
# [155367 rows x 7 columns]

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.22, random_state=42)
for train_index, test_index in split.split(data, data["Result"]):
 strat_train_set = data.loc[train_index]
 strat_test_set = data.loc[test_index]

# %%
data = strat_train_set.copy()
data = data.reset_index(drop=True)
data.drop('Unnamed: 0', axis=1,inplace=True)
data.to_csv('t.csv')
# data.columns

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()
Season = ordinal_encoder.fit_transform(pd.DataFrame(data['Season']))
Result = ordinal_encoder.fit_transform(pd.DataFrame(data['Result']))
Season = pd.DataFrame(Season)
Result = pd.DataFrame(Result)
data['Season'] = Season
data['Result'] = Result

# %%
from category_encoders import TargetEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 from category_encoders import TargetEncoder
#
# ModuleNotFoundError: No module named 'category_encoders'
